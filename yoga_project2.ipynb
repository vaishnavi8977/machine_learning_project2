# %%
pip install google-cloud-aiplatform
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (1.11.0)
# Requirement already satisfied: packaging>=14.3 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-cloud-aiplatform) (21.3)
# Requirement already satisfied: proto-plus>=1.15.0 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-cloud-aiplatform) (1.20.3)
# Requirement already satisfied: google-cloud-bigquery<3.0.0dev,>=1.15.0 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-cloud-aiplatform) (2.34.3)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-cloud-aiplatform) (2.5.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-cloud-aiplatform) (2.2.1)
# Requirement already satisfied: protobuf>=3.12.0 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (3.19.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (1.55.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (2.27.1)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (2.6.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (1.44.0)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (1.44.0)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-cloud-bigquery<3.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.3.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-cloud-bigquery<3.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.2.3)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-cloud-bigquery<3.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from packaging>=14.3->google-cloud-aiplatform) (3.0.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (4.8)
# Requirement already satisfied: six>=1.9.0 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (5.0.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<3.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/studio-lab-user/.conda/envs/gcp_env/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-aiplatform) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import io
from google.cloud import vision
from google.oauth2 import service_account

# %%
key_path = './smooth-command-342916-f08816206742.json'
credentials = service_account.Credentials.from_service_account_file(key_path)

# %%
import base64

from google.cloud import aiplatform
from google.cloud.aiplatform.gapic.schema import predict


def predict_image_classification_sample(
    project: str,
    endpoint_id: str,
    filename: str,
    location: str = "us-central1",
    api_endpoint: str = "us-central1-aiplatform.googleapis.com",
    credentials = credentials
):
    # The AI Platform services require regional API endpoints.
    client_options = {"api_endpoint": api_endpoint}
    # Initialize client that will be used to create and send requests.
    # This client only needs to be created once, and can be reused for multiple requests.
    client = aiplatform.gapic.PredictionServiceClient(client_options=client_options, credentials = credentials)
    with open(filename, "rb") as f:
        file_content = f.read()

    # The format of each instance should conform to the deployed model's prediction input schema.
    encoded_content = base64.b64encode(file_content).decode("utf-8")
    instance = predict.instance.ImageClassificationPredictionInstance(
        content=encoded_content,
    ).to_value()
    instances = [instance]
    # See gs://google-cloud-aiplatform/schema/predict/params/image_classification_1.0.0.yaml for the format of the parameters.
    parameters = predict.params.ImageClassificationPredictionParams(
        confidence_threshold=0.5, max_predictions=5,
    ).to_value()
    endpoint = client.endpoint_path(
        project=project, location=location, endpoint=endpoint_id
    )
    response = client.predict(
        endpoint=endpoint, instances=instances, parameters=parameters
    )
    print("response")
    print(" deployed_model_id:", response.deployed_model_id)
    # See gs://google-cloud-aiplatform/schema/predict/prediction/image_classification_1.0.0.yaml for the format of the predictions.
    predictions = response.predictions
    for prediction in predictions:
        print(" prediction:", dict(prediction))

# %%
predict_image_classification_sample(
    project="375688213202",
    endpoint_id="588960000487981056",
    location="us-central1",
    filename="test.png"
)
# Out:
# response
#  deployed_model_id: 7237346173835542528
#  prediction: {'confidences': [0.979314446], 'ids': ['2675129932320866304'], 'displayNames': ['bakasana']}
